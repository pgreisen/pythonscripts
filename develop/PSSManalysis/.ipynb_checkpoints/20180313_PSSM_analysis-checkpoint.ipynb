# %%
import pandas as pd

# %%
date = "2018nnn"

# %%
df_ = pd.read_csv("ascii_mtx_file",skiprows=2,skip_blank_lines=True,  delim_whitespace=True,header=0,
                  names=["WT",u'A', u'R', u'N', u'D', u'C', u'Q', u'E', u'G', u'H', u'I', u'L', u'K',
       u'M', u'F', u'P', u'S', u'T', u'W', u'Y', u'V', u'A.1', u'R.1', u'N.1',
       u'D.1', u'C.1', u'Q.1', u'E.1', u'G.1', u'H.1', u'I.1', u'L.1', u'K.1',
       u'M.1', u'F.1', u'P.1', u'S.1', u'T.1', u'W.1', u'Y.1', u'V.1',"S1","S2"],nrows=234)

# %%
df_["WT_score"] = 0.0
for index, row in df_.iterrows():
    df_.loc[index,"WT_score"] = df_.loc[index,df_.loc[index,"WT"]]

# %%
df_.head()
cols = [u'WT',u'A',u'R',        u'N',        u'D',
              u'C',        u'Q',        u'E',        u'G',        u'H',
              u'I',        u'L',        u'K',        u'M',        u'F',
              u'P',        u'S',        u'T',        u'W',        u'Y',
              u'V',     u'WT_score']
df_ = df_[cols]
df_.WT_score = df_.WT_score.astype(int)
df_.head()
# Out:
#   WT  A  R  N  D  C  Q  E   G  H    ...     K  M   F  P  S  T  W   Y   V  \
# 1  I -7 -9 -9 -9 -7 -9 -9 -10 -9    ...    -9 -5  -6 -9 -8 -7 -9  -7   3
# 2  V -3 -7 -8 -9 -6 -8 -8  -9 -8    ...    -5  0  -2 -8 -6 -3 -8  -3   7
# 3  G -5 -7  1 -5 -9 -4 -4   7 -2    ...    -5 -9  -9 -8 -4 -7 -9  -9  -9
# 4  G -5 -9 -7 -7 -9 -8 -9   8 -9    ...    -8 -9 -10 -9 -6 -8 -9 -10 -10
# 5  S -2  1  0 -1  0  2  2  -3  2    ...     0 -1   0 -4  0  1 -1   2   0
#
#    WT_score
# 1         8
# 2         7
# 3         7
# 4         8
# 5         0
#
# [5 rows x 22 columns]

# %%
# WT, Pos, AA, WT_score, AA_score, Diff_score
dffs = []
for index,row in df_.iterrows():
    for j in range(len(row)):
        if(j == 0):
            continue
        elif(df_.columns[j] == "WT_score"):
            continue
        elif(df_.columns[j] ==  df_.loc[index,"WT"] ):
            continue
        elif( row[j] > df_.loc[index,"WT_score"]):
            val_ = str( abs( df_.loc[index,"WT_score"] - row[j]  ) )
            tmp_ = df_.loc[index,"WT"]+","+str(index)+","+df_.columns[j]+","+str(df_.loc[index,"WT_score"])+","+str(row[j])+","+val_
            dffs.append(tmp_)
# Out:
# S,5,R,0,1,1
# S,5,Q,0,2,2
# S,5,E,0,2,2
# S,5,H,0,2,2
# S,5,T,0,1,1
# S,5,Y,0,2,2
# S,7,A,2,6,4
# S,7,C,2,6,4
# E,9,P,2,5,3
# A,11,E,1,3,2
# A,11,S,1,4,3
# V,15,Q,-3,9,12
# V,15,H,-3,-2,1
# V,15,I,-3,1,4
# V,15,M,-3,5,8
# A,17,S,2,6,4
# Y,19,R,2,4,2
# Y,19,Q,2,6,4
# Y,19,H,2,4,2
# F,20,Y,2,5,3
# D,21,R,0,3,3
# D,21,N,0,3,3
# D,21,G,0,1,1
# D,21,K,0,1,1
# D,21,S,0,1,1
# D,22,N,0,3,3
# D,22,G,0,5,5
# D,22,S,0,1,1
# Q,23,R,1,3,2
# Q,23,Y,1,3,2
# Q,24,H,0,10,10
# Q,24,F,0,3,3
# V,25,H,1,2,1
# V,25,I,1,2,1
# V,25,F,1,6,5
# V,25,W,1,2,1
# V,25,Y,1,2,1
# A,28,G,3,7,4
# V,31,I,2,8,6
# S,32,N,4,5,1
# R,33,N,0,3,3
# R,33,D,0,2,2
# R,33,E,0,3,3
# R,33,P,0,4,4
# R,33,S,0,2,2
# D,34,R,0,3,3
# D,34,N,0,2,2
# D,34,C,0,2,2
# D,34,Q,0,4,4
# D,34,H,0,1,1
# D,34,K,0,1,1
# D,34,W,0,1,1
# L,36,I,0,4,4
# L,36,V,0,7,7
# V,37,L,4,6,2
# S,38,T,3,8,5
# V,43,F,3,6,3
# E,49,N,1,2,1
# E,49,D,1,2,1
# K,52,N,1,2,1
# K,52,S,1,2,1
# K,54,R,2,4,2
# K,54,Q,2,3,1
# K,54,T,2,3,1
# A,55,I,1,2,1
# A,55,V,1,7,6
# V,56,R,3,4,1
# L,59,A,-1,1,2
# L,59,R,-1,0,1
# L,59,D,-1,2,3
# L,59,Q,-1,0,1
# L,59,E,-1,4,5
# L,59,I,-1,0,1
# L,59,K,-1,1,2
# L,59,T,-1,0,1
# M,61,R,-2,0,2
# M,61,N,-2,4,6
# M,61,D,-2,4,6
# M,61,Q,-2,1,3
# M,61,H,-2,2,4
# M,61,K,-2,0,2
# M,61,S,-2,1,3
# M,61,T,-2,-1,1
# M,61,Y,-2,0,2
# A,62,R,-2,2,4
# A,62,Q,-2,2,4
# A,62,I,-2,2,4
# A,62,L,-2,4,6
# A,62,M,-2,0,2
# A,62,F,-2,-1,1
# A,62,T,-2,-1,1
# A,62,V,-2,-1,1
# L,65,P,1,2,1
# T,66,D,2,3,1
# T,66,E,2,3,1
# S,67,E,2,3,1
# S,67,G,2,3,1
# Q,69,E,1,3,2
# Q,69,G,1,2,1
# Q,69,H,1,3,2
# I,70,A,0,1,1
# I,70,E,0,2,2
# I,70,G,0,1,1
# I,70,V,0,1,1
# E,71,Q,1,7,6
# L,74,A,-2,0,2
# L,74,R,-2,2,4
# L,74,N,-2,1,3
# L,74,D,-2,0,2
# L,74,Q,-2,0,2
# L,74,E,-2,1,3
# L,74,G,-2,0,2
# L,74,H,-2,-1,1
# L,74,K,-2,1,3
# L,74,P,-2,2,4
# L,74,S,-2,1,3
# L,74,T,-2,0,2
# L,74,Y,-2,0,2
# I,75,V,3,7,4
# D,76,Q,1,2,1
# D,76,E,1,2,1
# D,76,K,1,3,2
# D,76,S,1,2,1
# Q,77,R,3,5,2
# Q,77,K,3,4,1
# V,79,I,3,7,4
# N,81,H,1,11,10
# H,83,N,1,3,2
# H,83,D,1,3,2
# H,83,Q,1,2,1
# H,83,K,1,2,1
# K,86,P,1,3,2
# K,86,S,1,2,1
# R,87,N,1,2,1
# R,88,N,-1,3,4
# R,88,D,-1,0,1
# R,88,G,-1,0,1
# R,88,S,-1,1,2
# R,88,T,-1,5,6
# K,89,N,-1,0,1
# K,89,H,-1,3,4
# K,89,I,-1,2,3
# K,89,L,-1,1,2
# K,89,M,-1,2,3
# K,89,F,-1,3,4
# K,89,S,-1,0,1
# K,89,Y,-1,4,5
# K,89,V,-1,0,1
# N,90,D,3,5,2
# M,95,L,1,7,6
# M,96,I,3,4,1
# M,96,L,3,5,2
# H,97,R,3,4,1
# H,97,K,3,6,3
# E,99,S,2,3,1
# M,100,A,-3,-2,1
# M,100,R,-3,2,5
# M,100,N,-3,-1,2
# M,100,D,-3,-1,2
# M,100,Q,-3,2,5
# M,100,E,-3,2,5
# M,100,G,-3,-1,2
# M,100,H,-3,1,4
# M,100,K,-3,2,5
# M,100,P,-3,-2,1
# M,100,S,-3,3,6
# M,100,T,-3,2,5
# M,100,Y,-3,-2,1
# K,101,A,-1,0,1
# K,101,C,-1,2,3
# K,101,P,-1,7,8
# K,101,S,-1,0,1
# N,103,T,2,4,2
# Y,104,F,4,7,3
# T,105,N,4,5,1
# E,116,A,1,2,1
# E,116,K,1,2,1
# E,116,P,1,3,2
# E,116,S,1,2,1
# V,119,N,0,1,1
# V,119,D,0,1,1
# V,119,C,0,3,3
# V,119,Q,0,1,1
# V,119,E,0,1,1
# V,119,T,0,1,1
# R,124,T,1,5,4
# I,125,N,0,1,1
# I,125,Q,0,1,1
# I,125,E,0,1,1
# I,125,K,0,1,1
# I,125,M,0,2,2
# I,125,P,0,1,1
# I,125,S,0,1,1
# I,125,T,0,1,1
# S,127,R,-2,-1,1
# S,127,H,-2,0,2
# S,127,I,-2,1,3
# S,127,L,-2,0,2
# S,127,M,-2,0,2
# S,127,F,-2,1,3
# S,127,T,-2,2,4
# S,127,W,-2,9,11
# S,127,Y,-2,4,6
# S,127,V,-2,1,3
# I,128,V,5,7,2
# A,129,S,2,4,2
# A,129,T,2,6,4
# A,133,R,1,3,2
# A,133,N,1,2,1
# A,133,H,1,2,1
# L,134,T,3,6,3
# I,135,A,-3,-1,2
# I,135,R,-3,1,4
# I,135,N,-3,0,3
# I,135,D,-3,0,3
# I,135,Q,-3,3,6
# I,135,E,-3,1,4
# I,135,G,-3,-1,2
# I,135,H,-3,1,4
# I,135,L,-3,-2,1
# I,135,K,-3,2,5
# I,135,M,-3,-1,2
# I,135,F,-3,-1,2
# I,135,S,-3,2,5
# I,135,T,-3,0,3
# I,135,W,-3,-1,2
# I,135,Y,-3,0,3
# I,135,V,-3,-2,1
# Y,136,E,2,5,3
# Q,137,N,0,3,3
# Q,137,D,0,2,2
# Q,137,G,0,4,4
# Q,137,S,0,1,1
# S,139,P,2,4,2
# T,140,Y,2,3,1
# A,141,P,2,6,4
# A,141,S,2,4,2
# A,147,V,4,5,1
# D,148,Q,2,3,1
# D,148,E,2,3,1
# L,151,I,4,5,1
# L,152,I,2,6,4
# L,152,V,2,5,3
# K,156,Q,1,2,1
# K,156,E,1,2,1
# K,156,T,1,2,1
# Q,158,N,3,5,2
# Q,160,A,0,2,2
# Q,160,M,0,1,1
# Q,160,S,0,3,3
# Q,160,W,0,1,1
# Q,160,Y,0,1,1
# M,161,F,1,2,1
# M,161,W,1,5,4
# M,161,Y,1,8,7
# P,162,W,3,5,2
# P,162,Y,3,4,1
# E,163,N,1,3,2
# E,163,G,1,3,2
# Y,164,G,2,3,1
# E,168,D,3,5,2
# V,171,I,2,5,3
# V,171,L,2,4,2
# V,171,M,2,3,1
# V,171,F,2,4,2
# E,176,L,1,2,1
# E,176,M,1,2,1
# E,176,P,1,3,2
# A,177,D,1,3,2
# A,177,Q,1,2,1
# A,177,E,1,4,3
# V,180,K,2,6,4
# M,192,V,5,6,1
# E,195,D,1,2,1
# E,195,G,1,3,2
# N,197,G,2,5,3
# L,200,Q,-1,0,1
# L,200,H,-1,2,3
# L,200,I,-1,1,2
# L,200,F,-1,3,4
# L,200,T,-1,2,3
# L,200,W,-1,1,2
# L,200,Y,-1,5,6
# L,200,V,-1,2,3
# A,202,H,2,3,1
# A,202,V,2,4,2
# V,204,I,5,7,2
# T,205,V,4,7,3
# F,207,W,5,13,8
# Q,210,R,-3,-2,1
# Q,210,D,-3,-2,1
# Q,210,E,-3,-1,2
# Q,210,G,-3,7,10
# Q,210,K,-3,-1,2
# Q,210,P,-3,0,3
# Q,210,S,-3,-1,2
# L,213,R,0,4,4
# L,213,Q,0,3,3
# L,213,E,0,2,2
# L,213,K,0,2,2
# R,216,K,3,5,2
# R,216,Y,3,5,2
# A,221,T,2,7,5
# P,224,A,-1,1,2
# P,224,C,-1,4,5
# P,224,Q,-1,0,1
# P,224,S,-1,5,6
# P,224,T,-1,3,4
# R,225,Y,2,3,1
# F,226,Y,6,8,2
# T,227,R,1,3,2
# T,227,I,1,2,1
# T,227,L,1,2,1
# T,227,V,1,2,1
# E,228,N,1,2,1
# E,228,D,1,5,4
# E,228,P,1,2,1
# E,228,S,1,2,1
# S,232,Q,2,3,1
# S,232,E,2,3,1
# F,233,N,-2,0,2
# F,233,Q,-2,1,3
# F,233,H,-2,4,6
# F,233,I,-2,3,5
# F,233,K,-2,0,2
# F,233,M,-2,-1,1
# F,233,T,-2,4,6
# F,233,Y,-2,2,4
# F,233,V,-2,3,5
# L,234,I,1,6,5
# L,234,M,1,8,7
# L,234,V,1,2,1

# %%
with open(date+"stabilization_phylogenic.csv",'w') as f:
    f.write("WT, Pos, AA, WT_score, AA_score, Diff_score\n")
    for line in dffs:
        f.write(line+"\n")
df_.to_excel(date+"_PSSM_analysis.xlsx")
