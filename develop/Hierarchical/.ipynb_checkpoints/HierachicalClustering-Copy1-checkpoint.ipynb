# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset 
datatest = pd.read_csv("test.csv")
datatest.head(2)
#datatest = sns.load_dataset(datatest)
#datatest.head(2)
#print type(datatest)

#flights = datatest.pivot("Activity 1", "Activity 2")
#print flights
flights = sns.load_dataset("flights")
# print type(flights),type(datatest)
# <class 'pandas.core.frame.DataFrame'> <class 'pandas.core.frame.DataFrame'>
##print flights
flights = flights.pivot("month", "year", "passengers")
#print type(flights)
#print type(flights)
#g = sns.clustermap(datatest)
datatest.head(2)
##help(pd.pivot)
#pd.pivot_table(df, index='Date', columns='Location', values='Text', aggfunc=np.sum)

datatest = pd.pivot_table(datatest,index='SeqTag')

# %%
g = sns.clustermap(datatest)

# %%
g.savefig("output.png")

# %%
# %matplotlib inline
from Bio import Phylo
from Bio.Phylo.TreeConstruction import DistanceCalculator
from Bio.Phylo.TreeConstruction import DistanceTreeConstructor
from Bio import AlignIO
from scipy.cluster.hierarchy import dendrogram, linkage
import pylab as plt

aln = AlignIO.read('tot.aln', 'clustal')
#Computations for the unrooted tree
calculator = DistanceCalculator('identity')
dm = calculator.get_distance(aln)
#dists = squareform(dm)
linkage_matrix = linkage(dm, "single")

# %%
cg = sns.clustermap(datatest, row_linkage=linkage_matrix)
plt.setp(cg.ax_heatmap.yaxis.get_majorticklabels(), rotation=0)
plt.savefig("output_new.png")
