# %% [markdown]
# # Setup and run AWS instances

# %%
# !pip install boto3
import boto3
import pandas as pd
# Out:
# Requirement already satisfied: boto3 in /Users/pgreisen/anaconda2/lib/python2.7/site-packages
# Requirement already satisfied: s3transfer<0.2.0,>=0.1.10 in /Users/pgreisen/anaconda2/lib/python2.7/site-packages (from boto3)
# Requirement already satisfied: botocore<1.8.0,>=1.7.0 in /Users/pgreisen/anaconda2/lib/python2.7/site-packages (from boto3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /Users/pgreisen/anaconda2/lib/python2.7/site-packages (from boto3)
# Requirement already satisfied: futures<4.0.0,>=2.2.0; python_version == "2.6" or python_version == "2.7" in /Users/pgreisen/anaconda2/lib/python2.7/site-packages (from s3transfer<0.2.0,>=0.1.10->boto3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/pgreisen/anaconda2/lib/python2.7/site-packages (from botocore<1.8.0,>=1.7.0->boto3)
# Requirement already satisfied: docutils>=0.10 in /Users/pgreisen/anaconda2/lib/python2.7/site-packages (from botocore<1.8.0,>=1.7.0->boto3)
# Requirement already satisfied: six>=1.5 in /Users/pgreisen/anaconda2/lib/python2.7/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.8.0,>=1.7.0->boto3)

# %%
# see what is the spot prices in regions
ec2 = boto3.client('ec2')
response = ec2.describe_regions()
r_ = response['Regions']
#instance_type='m3.medium'
instance_type='m4.16xlarge'
tmp_dict_ = []
for i in r_:
    # print i['RegionName']
    client=boto3.client('ec2',region_name=i['RegionName'])
    response = client.describe_availability_zones()
    for j in response['AvailabilityZones']:
        # print j['RegionName'],j['ZoneName']
        prices =client.describe_spot_price_history(InstanceTypes=[instance_type],MaxResults=1\
                                                         ,ProductDescriptions=['Linux/UNIX (Amazon VPC)'],AvailabilityZone=j['ZoneName'])
        # print prices['SpotPriceHistory']
        try:
            tmp_dict_.append( prices['SpotPriceHistory'][0] )
        except:
            print "No pricing here: ", j['RegionName'],j['ZoneName']

df_ = pd.DataFrame(tmp_dict_)
df_.sort_values(by='SpotPrice', ascending=True).head(100)
# Out:
#    AvailabilityZone InstanceType ProductDescription  SpotPrice  \
# 13    ca-central-1a  m4.16xlarge         Linux/UNIX   0.444800
# 14    ca-central-1b  m4.16xlarge         Linux/UNIX   0.450600
# 8   ap-northeast-2c  m4.16xlarge         Linux/UNIX   0.528000
# 7   ap-northeast-2a  m4.16xlarge         Linux/UNIX   0.528000
# 3        eu-west-2b  m4.16xlarge         Linux/UNIX   0.530000
# 20    eu-central-1a  m4.16xlarge         Linux/UNIX   0.547200
# 29       us-east-2a  m4.16xlarge         Linux/UNIX   0.575400
# 30       us-east-2b  m4.16xlarge         Linux/UNIX   0.576300
# 31       us-east-2c  m4.16xlarge         Linux/UNIX   0.581900
# 15  ap-southeast-1a  m4.16xlarge         Linux/UNIX   0.603500
# 22    eu-central-1c  m4.16xlarge         Linux/UNIX   0.618000
# 18  ap-southeast-2b  m4.16xlarge         Linux/UNIX   0.674600
# 21    eu-central-1b  m4.16xlarge         Linux/UNIX   0.678000
# 19  ap-southeast-2c  m4.16xlarge         Linux/UNIX   0.678600
# 16  ap-southeast-1b  m4.16xlarge         Linux/UNIX   0.693600
# 4        eu-west-1a  m4.16xlarge         Linux/UNIX   0.861100
# 5        eu-west-1b  m4.16xlarge         Linux/UNIX   0.893800
# 6        eu-west-1c  m4.16xlarge         Linux/UNIX   0.975000
# 1       ap-south-1b  m4.16xlarge         Linux/UNIX   0.990000
# 2        eu-west-2a  m4.16xlarge         Linux/UNIX   1.039100
# 35       us-west-2b  m4.16xlarge         Linux/UNIX   1.094300
# 36       us-west-2c  m4.16xlarge         Linux/UNIX   1.094600
# 34       us-west-2a  m4.16xlarge         Linux/UNIX   1.131900
# 28       us-east-1f  m4.16xlarge         Linux/UNIX   1.176200
# 27       us-east-1e  m4.16xlarge         Linux/UNIX   1.182200
# 24       us-east-1b  m4.16xlarge         Linux/UNIX   1.192700
# 25       us-east-1c  m4.16xlarge         Linux/UNIX   1.220700
# 23       us-east-1a  m4.16xlarge         Linux/UNIX   1.236700
# 26       us-east-1d  m4.16xlarge         Linux/UNIX   1.265900
# 10  ap-northeast-1c  m4.16xlarge         Linux/UNIX   1.292000
# 9   ap-northeast-1a  m4.16xlarge         Linux/UNIX   1.292600
# 0       ap-south-1a  m4.16xlarge         Linux/UNIX   1.548000
# 33       us-west-1b  m4.16xlarge         Linux/UNIX   4.469000
# 32       us-west-1a  m4.16xlarge         Linux/UNIX  44.690000
# 17  ap-southeast-2a  m4.16xlarge         Linux/UNIX  53.810000
# 12       sa-east-1c  m4.16xlarge         Linux/UNIX  54.800000
# 11       sa-east-1a  m4.16xlarge         Linux/UNIX  54.800000
#
#                    Timestamp
# 13 2017-11-07 17:59:51+00:00
# 14 2017-11-07 18:12:16+00:00
# 8  2017-11-07 17:57:41+00:00
# 7  2017-11-07 17:57:41+00:00
# 3  2017-11-07 18:05:42+00:00
# 20 2017-11-07 18:03:32+00:00
# 29 2017-11-07 18:08:34+00:00
# 30 2017-11-07 18:07:52+00:00
# 31 2017-11-07 18:04:52+00:00
# 15 2017-11-07 18:09:58+00:00
# 22 2017-11-07 18:08:18+00:00
# 18 2017-11-07 17:58:30+00:00
# 21 2017-11-07 18:02:26+00:00
# 19 2017-11-07 18:11:30+00:00
# 16 2017-11-07 17:45:58+00:00
# 4  2017-11-07 18:02:39+00:00
# 5  2017-11-07 18:09:39+00:00
# 6  2017-11-07 18:06:39+00:00
# 1  2017-11-07 15:18:24+00:00
# 2  2017-11-07 17:44:42+00:00
# 35 2017-11-07 18:12:15+00:00
# 36 2017-11-07 18:09:23+00:00
# 34 2017-11-07 18:12:15+00:00
# 28 2017-11-07 15:19:27+00:00
# 27 2017-11-07 18:10:03+00:00
# 24 2017-11-07 18:11:05+00:00
# 25 2017-11-07 18:10:05+00:00
# 23 2017-11-07 18:10:07+00:00
# 26 2017-11-07 18:11:11+00:00
# 10 2017-11-07 16:43:25+00:00
# 9  2017-11-07 17:27:20+00:00
# 0  2017-11-07 18:04:43+00:00
# 33 2017-11-07 17:53:31+00:00
# 32 2017-11-07 15:54:06+00:00
# 17 2017-11-06 23:51:07+00:00
# 12 2017-11-07 12:30:53+00:00
# 11 2017-11-07 12:30:53+00:00

# %%
# create keys
# need to set these from the above information
# works but a time off set between file
# us-east-2c

rg_name = 'us-east-2'
av_zone = 'us-east-2c'

# subnet = 'subnet-0b8ec121'

kname = '5TestKey'
ec2 = boto3.resource('ec2', region_name=rg_name)
pth= '/Users/pgreisen/AWS/tmp_keys/'
projectname_key = pth+kname+'.pem'
try:
    key_pair = ec2.create_key_pair(KeyName=kname)
except:
    print "Key already exists"

KeyPairOut = str(key_pair.key_material)

# dump to file
with open(projectname_key,'w') as f:
    f.write(KeyPairOut)
# Out:
# Key already exists
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-96-20f639b78de8> in <module>()
#      21
#      22 # dump to file
# ---> 23 with open(projectname_key,'w') as f:
#      24     f.write(KeyPairOut)
#
# IOError: [Errno 13] Permission denied: '/Users/pgreisen/AWS/tmp_keys/5TestKey.pem'

# %%
ImageId='ami-c7ee5ca8'

# %%
import boto3
ec2 = boto3.resource('ec2', region_name=rg_name)
client = boto3.client('ec2')
filters = [{'Name':'tag:Name', 'Values':['VPN*']}]
vpcs = list(ec2.vpcs.filter(Filters=filters))

# %%
#https://gist.github.com/nguyendv/8cfd92fc8ed32ebb78e366f44c2daea6

# create VPC
vpc = ec2.create_vpc(CidrBlock='192.168.0.0/16')
# we can assign a name to vpc, or any resource, by using tag
vpc.create_tags(Tags=[{"Key": "Name", "Value": "default_vpc"}])
vpc.wait_until_available()
print(vpc.id)

# create then attach internet gateway
ig = ec2.create_internet_gateway()
vpc.attach_internet_gateway(InternetGatewayId=ig.id)
print(ig.id)

# create a route table and a public route
route_table = vpc.create_route_table()
route = route_table.create_route(
    DestinationCidrBlock='0.0.0.0/0',
    GatewayId=ig.id
)
print(route_table.id)

# create subnet
subnet = ec2.create_subnet(CidrBlock='192.168.1.0/24', AvailabilityZone=av_zone, VpcId=vpc.id)
print(subnet.id)

# associate the route table with the subnet
route_table.associate_with_subnet(SubnetId=subnet.id)

# Create sec group
sec_group = ec2.create_security_group(
    GroupName='slice_0', Description='slice_0 sec group', VpcId=vpc.id)
sec_group.authorize_ingress(
    CidrIp='0.0.0.0/0',
    # changed by PJG 2017-11-07 
    # IpProtocol='icmp',
    IpProtocol='tcp',
    FromPort=22,
    ToPort=22
)
print(sec_group.id)
# Out:
# vpc-cdcfd2a4
# igw-711a5118
# rtb-15f30d7d
# subnet-0a086b47
# sg-45017d2d

# %%
# Ubuntu Server 16.04 LTS (HVM), SSD Volume Type - ami-cd0f5cb6
# Amazon Linux AMI 2017.09.0 (HVM), SSD Volume Type - ami-8c1be5f6
# Deep Learning AMI Ubuntu Version 2.4_Oct2017 - ami-37bb714d
# Deep Learning AMI Amazon Linux Version 3.3_Oct2017 - ami-78994d02
import boto3
# ec2 = boto3.resource('ec2')
ec2 = boto3.resource('ec2', region_name=rg_name)

instance = ec2.create_instances(
    ImageId="ami-c5062ba0", #ImageId,
    MinCount=1,
    MaxCount=1,
    KeyName=kname,
    Placement={'AvailabilityZone': av_zone },
    #SecurityGroupIds=[sg.id],
    #SecurityGroupIds=[sec_group.id],
    #SubnetId=subnet.id,
    InstanceType='t2.nano',
    # 2017-11-06
    
    NetworkInterfaces=\
    [{'SubnetId': subnet.id, 
      'DeviceIndex': 0, 
      'AssociatePublicIpAddress': True, 
      'Groups': [sec_group.group_id]
     }])
print instance[0].id


# Wait for the instance to enter the running state
instance[0].wait_until_running()

# Reload the instance attributes
instance[0].load()
print(instance.public_dns_name)
# Out:
# i-07b50c88399ea7ee6
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-ed3e0170f25b> in <module>()
#      32
#      33 # Reload the instance attributes
# ---> 34 instance.load()
#      35 print(instance.public_dns_name)
#
# AttributeError: 'list' object has no attribute 'load'

# %%
import boto3
client = boto3.client('ec2')
addresses_dict = client.describe_addresses()
for eip_dict in addresses_dict['Addresses']:
    print eip_dict['PublicIp']
# Out:
# 52.54.56.231

# %%
from collections import defaultdict

import boto3

"""
A tool for retrieving basic information from the running EC2 instances.
"""

# Connect to EC2
ec2 = boto3.resource('ec2')

# Get information for all running instances
running_instances = ec2.instances.filter(Filters=[{
    'Name': 'instance-state-name',
    'Values': ['running']}])


ec2info = defaultdict()
for instance in running_instances:
    for tag in instance.tags:
        if 'Name'in tag['Key']:
            name = tag['Value']
    # Add instance info to a dictionary         
    ec2info[instance.id] = {
        'Name': name,
        'Type': instance.instance_type,
        'State': instance.state['Name'],
        'Private IP': instance.private_ip_address,
        'Public IP': instance.public_ip_address,
        'Launch Time': instance.launch_time
        }
attributes = ['Name', 'Type', 'State', 'Private IP', 'Public IP', 'Launch Time']

for instance_id, instance in ec2info.items():
    for key in attributes:
        print("{0}: {1}".format(key, instance[key]))
    print("------")

# %%
ec2 = boto3.resource("ec2")
for vpc in ec2.vpcs.all():
    for subnet in vpc.subnets.all():
        print(vpc, "all:", subnet)
    for az in ec2.meta.client.describe_availability_zones()["AvailabilityZones"]:
        for subnet in vpc.subnets.filter(Filters=[{"Name": "availabilityZone", "Values": [az["ZoneName"]]}]):
            print(vpc, az["ZoneName"], "filter:", subnet)
# Out:
# (ec2.Vpc(id='vpc-88f051ef'), 'all:', ec2.Subnet(id='subnet-0b8ec121'))
# (ec2.Vpc(id='vpc-88f051ef'), 'all:', ec2.Subnet(id='subnet-c9784df4'))
# (ec2.Vpc(id='vpc-88f051ef'), 'all:', ec2.Subnet(id='subnet-4ef8b016'))
# (ec2.Vpc(id='vpc-88f051ef'), 'all:', ec2.Subnet(id='subnet-4aaf903c'))
# (ec2.Vpc(id='vpc-88f051ef'), 'all:', ec2.Subnet(id='subnet-28dc6424'))
# (ec2.Vpc(id='vpc-88f051ef'), 'all:', ec2.Subnet(id='subnet-86bb27e3'))
# (ec2.Vpc(id='vpc-88f051ef'), 'us-east-1a', 'filter:', ec2.Subnet(id='subnet-86bb27e3'))
# (ec2.Vpc(id='vpc-88f051ef'), 'us-east-1b', 'filter:', ec2.Subnet(id='subnet-0b8ec121'))
# (ec2.Vpc(id='vpc-88f051ef'), 'us-east-1c', 'filter:', ec2.Subnet(id='subnet-4aaf903c'))
# (ec2.Vpc(id='vpc-88f051ef'), 'us-east-1d', 'filter:', ec2.Subnet(id='subnet-4ef8b016'))
# (ec2.Vpc(id='vpc-88f051ef'), 'us-east-1e', 'filter:', ec2.Subnet(id='subnet-c9784df4'))
# (ec2.Vpc(id='vpc-88f051ef'), 'us-east-1f', 'filter:', ec2.Subnet(id='subnet-28dc6424'))
# (ec2.Vpc(id='vpc-f4250793'), 'all:', ec2.Subnet(id='subnet-7ee51753'))
# (ec2.Vpc(id='vpc-f4250793'), 'us-east-1b', 'filter:', ec2.Subnet(id='subnet-7ee51753'))

# %%
ClientError: An error occurred (InvalidParameterValue) when calling the RunInstances operation: Value (eu-west-2a) for parameter availabilityZone is invalid. Subnet 'subnet-296efd64' is in the availability zone eu-west-2b
